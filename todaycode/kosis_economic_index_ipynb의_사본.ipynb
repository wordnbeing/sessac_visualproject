# %% [markdown]
# ## 경기종합지수(2020=100)(10차)
# https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1C8015&conn_path=I2

# %% [markdown]
# * 오늘코드 유튜브 채널 설명 영상 : https://youtu.be/c62S-WZtVJ4

# %%
# !pip install koreanize-matplotlib

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
# df = pd.read_csv("data/kosis-economic-index.csv", encoding="cp949", index_col="시점")
df = pd.read_csv("data/kosis-economic-index.csv", encoding="cp949" )#, index_col="시점")
# df = df.set_index("시점")
df.head(2)
# Out:
#                 지수별      항목  단위  1970.01 월  1970.02 월  1970.03 월  1970.04 월  \
# 0  선행종합지수(2020=100)  경기종합지수 NaN        3.7        3.7        3.8        3.8
# 1     선행종합지수 전월비(%)  경기종합지수 NaN        0.0        0.0        2.7        0.0
#
#    1970.05 월  1970.06 월  1970.07 월  ...  2022.12 월  2023.01 월  2023.02 월  \
# 0        3.8        3.8        3.9  ...      109.5      109.4      109.3
# 1        0.0        0.0        2.6  ...       -0.2       -0.1       -0.1
#
#    2023.03 월  2023.04 월  2023.05 월  2023.06 월  2023.07 월  2023.08 월  \
# 0      109.4      109.4      109.8      110.5      111.1      111.4
# 1        0.1        0.0        0.4        0.6        0.5        0.3
#
#    Unnamed: 647
# 0           NaN
# 1           NaN
#
# [2 rows x 648 columns]

# %%
df.columns
# Out:
# Index(['지수별', '항목', '단위', '1970.01 월', '1970.02 월', '1970.03 월', '1970.04 월',
#        '1970.05 월', '1970.06 월', '1970.07 월',
#        ...
#        '2022.12 월', '2023.01 월', '2023.02 월', '2023.03 월', '2023.04 월',
#        '2023.05 월', '2023.06 월', '2023.07 월', '2023.08 월', 'Unnamed: 647'],
#       dtype='object', length=648)

# %%
df = df.drop(df.columns[[1, 2, -1]], axis=1)
df.head(2)
# Out:
#                 지수별  1970.01 월  1970.02 월  1970.03 월  1970.04 월  1970.05 월  \
# 0  선행종합지수(2020=100)        3.7        3.7        3.8        3.8        3.8
# 1     선행종합지수 전월비(%)        0.0        0.0        2.7        0.0        0.0
#
#    1970.06 월  1970.07 월  1970.08 월  1970.09 월  ...  2022.11 월  2022.12 월  \
# 0        3.8        3.9        3.9        3.9  ...      109.7      109.5
# 1        0.0        2.6        0.0        0.0  ...        0.0       -0.2
#
#    2023.01 월  2023.02 월  2023.03 월  2023.04 월  2023.05 월  2023.06 월  \
# 0      109.4      109.3      109.4      109.4      109.8      110.5
# 1       -0.1       -0.1        0.1        0.0        0.4        0.6
#
#    2023.07 월  2023.08 월
# 0      111.1      111.4
# 1        0.5        0.3
#
# [2 rows x 645 columns]

# %%
df = df.set_index('지수별')
df
# Out:
#                           1970.01 월  1970.02 월  1970.03 월  1970.04 월  \
# 지수별
# 선행종합지수(2020=100)                3.7        3.7        3.8        3.8
# 선행종합지수 전월비(%)                   0.0        0.0        2.7        0.0
# 재고순환지표(전월차)(%p)                 NaN        NaN        NaN        NaN
# 경제심리지수(전월차)(p)                  NaN        NaN        NaN        NaN
# 기계류내수출하지수(선박제외)(전월비)(%)         NaN        NaN        NaN        NaN
# 건설수주액(전월비)(%)                   NaN        NaN        NaN        NaN
# 수출입물가비율(전월비)(%)                 NaN        NaN        NaN        NaN
# 코스피(전월비)(%)                     NaN        NaN        NaN        NaN
# 장단기금리차(전월차)(%p)                 NaN        NaN        NaN        NaN
# 선행지수 순환변동치                    101.0      100.9      100.8      100.6
# 〔순환변동치 전월차〕(p)                  0.0       -0.1       -0.1       -0.2
# 선행지수 전년동월비(%)                   0.0        0.0        0.0        0.0
# 〔전년동월비 전월차〕(%p)                 0.0        0.0        0.0        0.0
# 동행종합지수(2020=100)                3.6        3.7        3.8        3.8
# 동행종합지수 전월비(%)                   0.0        2.8        2.7        0.0
# 광공업생산지수(전월비)(%)                 NaN        NaN        NaN        NaN
# 서비스업생산지수(도소매업제외)(전월비)(%)        NaN        NaN        NaN        NaN
# 건설기성액(전월비)(%)                   NaN        NaN        NaN        NaN
# 소매판매액지수(전월비)(%)                 NaN        NaN        NaN        NaN
# 내수출하지수(전월비)(%)                  NaN        NaN        NaN        NaN
# 수입액(전월비)(%)                     NaN        NaN        NaN        NaN
# 비농림어업취업자수(전월비)(%)               NaN        NaN        NaN        NaN
# 동행지수 순환변동치                    100.6      101.5      101.9      103.2
# 〔순환변동치 전월차〕(p)                  0.0        0.9        0.4        1.3
# 후행종합지수(2020=100)                3.6        3.6        3.8        3.8
# 후행종합지수 전월비(%)                   0.0        0.0        5.6        0.0
# 생산자제품재고지수(전월비)(%)               NaN        NaN        NaN        NaN
# 소비자물가지수변화율(서비스)(전월차)(%p)        NaN        NaN        NaN        NaN
# 소비재수입액(전월비)(%)                  NaN        NaN        NaN        NaN
# 취업자수(전월비)(%)                    NaN        NaN        NaN        NaN
# CP유통수익률(전월차)(%p)                NaN        NaN        NaN        NaN
#
#                           1970.05 월  1970.06 월  1970.07 월  1970.08 월  \
# 지수별
# 선행종합지수(2020=100)                3.8        3.8        3.9        3.9
# 선행종합지수 전월비(%)                   0.0        0.0        2.6        0.0
# 재고순환지표(전월차)(%p)                 NaN        NaN        NaN        NaN
# 경제심리지수(전월차)(p)                  NaN        NaN        NaN        NaN
# 기계류내수출하지수(선박제외)(전월비)(%)         NaN        NaN        NaN        NaN
# 건설수주액(전월비)(%)                   NaN        NaN        NaN        NaN
# 수출입물가비율(전월비)(%)                 NaN        NaN        NaN        NaN
# 코스피(전월비)(%)                     NaN        NaN        NaN        NaN
# 장단기금리차(전월차)(%p)                 NaN        NaN        NaN        NaN
# 선행지수 순환변동치                    100.5      100.3      100.2      100.0
# 〔순환변동치 전월차〕(p)                 -0.1       -0.2       -0.1       -0.2
# 선행지수 전년동월비(%)                   0.0        0.0        0.0        0.0
# 〔전년동월비 전월차〕(%p)                 0.0        0.0        0.0        0.0
# 동행종합지수(2020=100)                3.9        3.9        4.0        4.0
# 동행종합지수 전월비(%)                   2.6        0.0        2.6        0.0
# 광공업생산지수(전월비)(%)                 NaN        NaN        NaN        NaN
# 서비스업생산지수(도소매업제외)(전월비)(%)        NaN        NaN        NaN        NaN
# 건설기성액(전월비)(%)                   NaN        NaN        NaN        NaN
# 소매판매액지수(전월비)(%)                 NaN        NaN        NaN        NaN
# 내수출하지수(전월비)(%)                  NaN        NaN        NaN        NaN
# 수입액(전월비)(%)                     NaN        NaN        NaN        NaN
# 비농림어업취업자수(전월비)(%)               NaN        NaN        NaN        NaN
# 동행지수 순환변동치                    103.2      103.2      103.0      102.6
# 〔순환변동치 전월차〕(p)                  0.0        0.0       -0.2       -0.4
# 후행종합지수(2020=100)                3.8        4.0        4.0        4.0
# 후행종합지수 전월비(%)                   0.0        5.3        0.0        0.0
# 생산자제품재고지수(전월비)(%)               NaN        NaN        NaN        NaN
# 소비자물가지수변화율(서비스)(전월차)(%p)        NaN        NaN        NaN        NaN
# 소비재수입액(전월비)(%)                  NaN        NaN        NaN        NaN
# 취업자수(전월비)(%)                    NaN        NaN        NaN        NaN
# CP유통수익률(전월차)(%p)                NaN        NaN        NaN        NaN
#
#                           1970.09 월  1970.10 월  ...  2022.11 월  2022.12 월  \
# 지수별                                             ...
# 선행종합지수(2020=100)                3.9        4.0  ...     109.70     109.50
# 선행종합지수 전월비(%)                   0.0        2.6  ...       0.00      -0.20
# 재고순환지표(전월차)(%p)                 NaN        NaN  ...      -1.40      -2.80
# 경제심리지수(전월차)(p)                  NaN        NaN  ...      -2.70      -2.20
# 기계류내수출하지수(선박제외)(전월비)(%)         NaN        NaN  ...       0.40      -0.30
# 건설수주액(전월비)(%)                   NaN        NaN  ...      -8.70     -21.00
# 수출입물가비율(전월비)(%)                 NaN        NaN  ...      -0.20       0.20
# 코스피(전월비)(%)                     NaN        NaN  ...      -0.90       0.40
# 장단기금리차(전월차)(%p)                 NaN        NaN  ...      -0.06      -0.35
# 선행지수 순환변동치                     99.8       99.7  ...     100.10      99.60
# 〔순환변동치 전월차〕(p)                 -0.2       -0.1  ...      -0.20      -0.50
# 선행지수 전년동월비(%)                   0.0        0.0  ...       2.10       1.80
# 〔전년동월비 전월차〕(%p)                 0.0        0.0  ...      -0.10      -0.30
# 동행종합지수(2020=100)                4.0        4.0  ...     108.90     108.40
# 동행종합지수 전월비(%)                   0.0        0.0  ...      -0.50      -0.50
# 광공업생산지수(전월비)(%)                 NaN        NaN  ...      -1.70      -2.40
# 서비스업생산지수(도소매업제외)(전월비)(%)        NaN        NaN  ...      -0.20       0.30
# 건설기성액(전월비)(%)                   NaN        NaN  ...       1.50       0.80
# 소매판매액지수(전월비)(%)                 NaN        NaN  ...      -1.50      -0.50
# 내수출하지수(전월비)(%)                  NaN        NaN  ...      -1.10      -1.00
# 수입액(전월비)(%)                     NaN        NaN  ...      -1.10      -2.70
# 비농림어업취업자수(전월비)(%)               NaN        NaN  ...       0.00      -0.10
# 동행지수 순환변동치                    102.7      102.1  ...     100.50      99.80
# 〔순환변동치 전월차〕(p)                  0.1       -0.6  ...      -0.60      -0.70
# 후행종합지수(2020=100)                4.1        4.2  ...     111.80     112.40
# 후행종합지수 전월비(%)                   2.5        2.4  ...       0.40       0.50
# 생산자제품재고지수(전월비)(%)               NaN        NaN  ...       0.90       0.70
# 소비자물가지수변화율(서비스)(전월차)(%p)        NaN        NaN  ...       0.00      -0.10
# 소비재수입액(전월비)(%)                  NaN        NaN  ...      -2.70      -2.30
# 취업자수(전월비)(%)                    NaN        NaN  ...       0.00      -0.10
# CP유통수익률(전월차)(%p)                NaN        NaN  ...       0.80       0.80
#
#                           2023.01 월  2023.02 월  2023.03 월  2023.04 월  \
# 지수별
# 선행종합지수(2020=100)             109.40     109.30     109.40     109.40
# 선행종합지수 전월비(%)                 -0.10      -0.10       0.10       0.00
# 재고순환지표(전월차)(%p)               -5.00      -0.80      -0.30      -0.30
# 경제심리지수(전월차)(p)                -1.80       0.10       0.00       1.20
# 기계류내수출하지수(선박제외)(전월비)(%)       -4.90      -3.20      -4.20      -1.60
# 건설수주액(전월비)(%)                 30.40       4.90      -4.20     -25.10
# 수출입물가비율(전월비)(%)               -0.10      -0.60      -0.20       0.10
# 코스피(전월비)(%)                    1.90       0.50       0.80       2.20
# 장단기금리차(전월차)(%p)               -0.39      -0.27      -0.11      -0.12
# 선행지수 순환변동치                    99.20      99.00      98.70      98.50
# 〔순환변동치 전월차〕(p)                -0.40      -0.20      -0.30      -0.20
# 선행지수 전년동월비(%)                  1.50       1.30       1.20       1.10
# 〔전년동월비 전월차〕(%p)               -0.30      -0.20      -0.10      -0.10
# 동행종합지수(2020=100)             108.20     108.70     109.50     110.00
# 동행종합지수 전월비(%)                 -0.20       0.50       0.70       0.50
# 광공업생산지수(전월비)(%)               -0.80      -1.40       1.30       0.40
# 서비스업생산지수(도소매업제외)(전월비)(%)      -0.10       1.00       0.30       0.80
# 건설기성액(전월비)(%)                  0.90       2.30       1.40       0.10
# 소매판매액지수(전월비)(%)               -1.30       1.30       1.10       0.80
# 내수출하지수(전월비)(%)                -0.20       0.00       0.40      -0.70
# 수입액(전월비)(%)                   -1.40       0.50       0.20      -0.20
# 비농림어업취업자수(전월비)(%)             -0.10       0.40       0.40       0.40
# 동행지수 순환변동치                    99.30      99.60     100.10     100.30
# 〔순환변동치 전월차〕(p)                -0.50       0.30       0.50       0.20
# 후행종합지수(2020=100)             112.80     112.90     113.10     113.40
# 후행종합지수 전월비(%)                  0.40       0.10       0.20       0.30
# 생산자제품재고지수(전월비)(%)              1.80       1.00       0.90       1.90
# 소비자물가지수변화율(서비스)(전월차)(%p)      -0.10      -0.10       0.00       0.00
# 소비재수입액(전월비)(%)                -0.10       0.10       0.90      -1.00
# 취업자수(전월비)(%)                  -0.10       0.20       0.40       0.40
# CP유통수익률(전월차)(%p)               0.30      -0.30      -0.50      -0.30
#
#                           2023.05 월  2023.06 월  2023.07 월  2023.08 월
# 지수별
# 선행종합지수(2020=100)              109.8     110.50     111.10     111.40
# 선행종합지수 전월비(%)                   0.4       0.60       0.50       0.30
# 재고순환지표(전월차)(%p)                -0.5       4.20       3.40       1.60
# 경제심리지수(전월차)(p)                  0.9       1.40       0.10      -0.10
# 기계류내수출하지수(선박제외)(전월비)(%)        -1.4      -0.90       0.40      -0.30
# 건설수주액(전월비)(%)                   0.2      13.00       2.90     -21.30
# 수출입물가비율(전월비)(%)                 0.9       0.80       0.70       0.10
# 코스피(전월비)(%)                     1.0       2.40       0.90       0.50
# 장단기금리차(전월차)(%p)                -0.1      -0.01       0.11       0.16
# 선행지수 순환변동치                     98.6      98.90      99.30      99.30
# 〔순환변동치 전월차〕(p)                  0.1       0.30       0.40       0.00
# 선행지수 전년동월비(%)                   1.2       1.60       2.10       2.20
# 〔전년동월비 전월차〕(%p)                 0.1       0.40       0.50       0.10
# 동행종합지수(2020=100)              110.3     110.30     110.00     110.10
# 동행종합지수 전월비(%)                   0.3       0.00      -0.30       0.10
# 광공업생산지수(전월비)(%)                 2.4       0.30      -0.20       0.60
# 서비스업생산지수(도소매업제외)(전월비)(%)       -0.4      -0.20      -0.10       0.50
# 건설기성액(전월비)(%)                  -0.8      -0.10      -0.20       1.00
# 소매판매액지수(전월비)(%)                -0.7      -0.40      -0.60      -0.90
# 내수출하지수(전월비)(%)                  0.3       0.10       0.20      -0.30
# 수입액(전월비)(%)                     1.4      -0.40      -3.10      -1.10
# 비농림어업취업자수(전월비)(%)               0.1       0.00      -0.10      -0.10
# 동행지수 순환변동치                    100.3     100.10      99.60      99.40
# 〔순환변동치 전월차〕(p)                  0.0      -0.20      -0.50      -0.20
# 후행종합지수(2020=100)              113.7     113.90     113.80     113.90
# 후행종합지수 전월비(%)                   0.3       0.20      -0.10       0.10
# 생산자제품재고지수(전월비)(%)               1.7       0.00      -1.30      -0.20
# 소비자물가지수변화율(서비스)(전월차)(%p)        0.0      -0.20      -0.30      -0.20
# 소비재수입액(전월비)(%)                 -2.1       1.90      -2.20      -1.10
# 취업자수(전월비)(%)                    0.2       0.00      -0.10      -0.10
# CP유통수익률(전월차)(%p)               -0.1       0.00       0.00       0.00
#
# [31 rows x 644 columns]

# %%
df
# Out:
#                           1970.01 월  1970.02 월  1970.03 월  1970.04 월  \
# 지수별
# 선행종합지수(2020=100)                3.7        3.7        3.8        3.8
# 선행종합지수 전월비(%)                   0.0        0.0        2.7        0.0
# 재고순환지표(전월차)(%p)                 NaN        NaN        NaN        NaN
# 경제심리지수(전월차)(p)                  NaN        NaN        NaN        NaN
# 기계류내수출하지수(선박제외)(전월비)(%)         NaN        NaN        NaN        NaN
# 건설수주액(전월비)(%)                   NaN        NaN        NaN        NaN
# 수출입물가비율(전월비)(%)                 NaN        NaN        NaN        NaN
# 코스피(전월비)(%)                     NaN        NaN        NaN        NaN
# 장단기금리차(전월차)(%p)                 NaN        NaN        NaN        NaN
# 선행지수 순환변동치                    101.0      100.9      100.8      100.6
# 〔순환변동치 전월차〕(p)                  0.0       -0.1       -0.1       -0.2
# 선행지수 전년동월비(%)                   0.0        0.0        0.0        0.0
# 〔전년동월비 전월차〕(%p)                 0.0        0.0        0.0        0.0
# 동행종합지수(2020=100)                3.6        3.7        3.8        3.8
# 동행종합지수 전월비(%)                   0.0        2.8        2.7        0.0
# 광공업생산지수(전월비)(%)                 NaN        NaN        NaN        NaN
# 서비스업생산지수(도소매업제외)(전월비)(%)        NaN        NaN        NaN        NaN
# 건설기성액(전월비)(%)                   NaN        NaN        NaN        NaN
# 소매판매액지수(전월비)(%)                 NaN        NaN        NaN        NaN
# 내수출하지수(전월비)(%)                  NaN        NaN        NaN        NaN
# 수입액(전월비)(%)                     NaN        NaN        NaN        NaN
# 비농림어업취업자수(전월비)(%)               NaN        NaN        NaN        NaN
# 동행지수 순환변동치                    100.6      101.5      101.9      103.2
# 〔순환변동치 전월차〕(p)                  0.0        0.9        0.4        1.3
# 후행종합지수(2020=100)                3.6        3.6        3.8        3.8
# 후행종합지수 전월비(%)                   0.0        0.0        5.6        0.0
# 생산자제품재고지수(전월비)(%)               NaN        NaN        NaN        NaN
# 소비자물가지수변화율(서비스)(전월차)(%p)        NaN        NaN        NaN        NaN
# 소비재수입액(전월비)(%)                  NaN        NaN        NaN        NaN
# 취업자수(전월비)(%)                    NaN        NaN        NaN        NaN
# CP유통수익률(전월차)(%p)                NaN        NaN        NaN        NaN
#
#                           1970.05 월  1970.06 월  1970.07 월  1970.08 월  \
# 지수별
# 선행종합지수(2020=100)                3.8        3.8        3.9        3.9
# 선행종합지수 전월비(%)                   0.0        0.0        2.6        0.0
# 재고순환지표(전월차)(%p)                 NaN        NaN        NaN        NaN
# 경제심리지수(전월차)(p)                  NaN        NaN        NaN        NaN
# 기계류내수출하지수(선박제외)(전월비)(%)         NaN        NaN        NaN        NaN
# 건설수주액(전월비)(%)                   NaN        NaN        NaN        NaN
# 수출입물가비율(전월비)(%)                 NaN        NaN        NaN        NaN
# 코스피(전월비)(%)                     NaN        NaN        NaN        NaN
# 장단기금리차(전월차)(%p)                 NaN        NaN        NaN        NaN
# 선행지수 순환변동치                    100.5      100.3      100.2      100.0
# 〔순환변동치 전월차〕(p)                 -0.1       -0.2       -0.1       -0.2
# 선행지수 전년동월비(%)                   0.0        0.0        0.0        0.0
# 〔전년동월비 전월차〕(%p)                 0.0        0.0        0.0        0.0
# 동행종합지수(2020=100)                3.9        3.9        4.0        4.0
# 동행종합지수 전월비(%)                   2.6        0.0        2.6        0.0
# 광공업생산지수(전월비)(%)                 NaN        NaN        NaN        NaN
# 서비스업생산지수(도소매업제외)(전월비)(%)        NaN        NaN        NaN        NaN
# 건설기성액(전월비)(%)                   NaN        NaN        NaN        NaN
# 소매판매액지수(전월비)(%)                 NaN        NaN        NaN        NaN
# 내수출하지수(전월비)(%)                  NaN        NaN        NaN        NaN
# 수입액(전월비)(%)                     NaN        NaN        NaN        NaN
# 비농림어업취업자수(전월비)(%)               NaN        NaN        NaN        NaN
# 동행지수 순환변동치                    103.2      103.2      103.0      102.6
# 〔순환변동치 전월차〕(p)                  0.0        0.0       -0.2       -0.4
# 후행종합지수(2020=100)                3.8        4.0        4.0        4.0
# 후행종합지수 전월비(%)                   0.0        5.3        0.0        0.0
# 생산자제품재고지수(전월비)(%)               NaN        NaN        NaN        NaN
# 소비자물가지수변화율(서비스)(전월차)(%p)        NaN        NaN        NaN        NaN
# 소비재수입액(전월비)(%)                  NaN        NaN        NaN        NaN
# 취업자수(전월비)(%)                    NaN        NaN        NaN        NaN
# CP유통수익률(전월차)(%p)                NaN        NaN        NaN        NaN
#
#                           1970.09 월  1970.10 월  ...  2022.11 월  2022.12 월  \
# 지수별                                             ...
# 선행종합지수(2020=100)                3.9        4.0  ...     109.70     109.50
# 선행종합지수 전월비(%)                   0.0        2.6  ...       0.00      -0.20
# 재고순환지표(전월차)(%p)                 NaN        NaN  ...      -1.40      -2.80
# 경제심리지수(전월차)(p)                  NaN        NaN  ...      -2.70      -2.20
# 기계류내수출하지수(선박제외)(전월비)(%)         NaN        NaN  ...       0.40      -0.30
# 건설수주액(전월비)(%)                   NaN        NaN  ...      -8.70     -21.00
# 수출입물가비율(전월비)(%)                 NaN        NaN  ...      -0.20       0.20
# 코스피(전월비)(%)                     NaN        NaN  ...      -0.90       0.40
# 장단기금리차(전월차)(%p)                 NaN        NaN  ...      -0.06      -0.35
# 선행지수 순환변동치                     99.8       99.7  ...     100.10      99.60
# 〔순환변동치 전월차〕(p)                 -0.2       -0.1  ...      -0.20      -0.50
# 선행지수 전년동월비(%)                   0.0        0.0  ...       2.10       1.80
# 〔전년동월비 전월차〕(%p)                 0.0        0.0  ...      -0.10      -0.30
# 동행종합지수(2020=100)                4.0        4.0  ...     108.90     108.40
# 동행종합지수 전월비(%)                   0.0        0.0  ...      -0.50      -0.50
# 광공업생산지수(전월비)(%)                 NaN        NaN  ...      -1.70      -2.40
# 서비스업생산지수(도소매업제외)(전월비)(%)        NaN        NaN  ...      -0.20       0.30
# 건설기성액(전월비)(%)                   NaN        NaN  ...       1.50       0.80
# 소매판매액지수(전월비)(%)                 NaN        NaN  ...      -1.50      -0.50
# 내수출하지수(전월비)(%)                  NaN        NaN  ...      -1.10      -1.00
# 수입액(전월비)(%)                     NaN        NaN  ...      -1.10      -2.70
# 비농림어업취업자수(전월비)(%)               NaN        NaN  ...       0.00      -0.10
# 동행지수 순환변동치                    102.7      102.1  ...     100.50      99.80
# 〔순환변동치 전월차〕(p)                  0.1       -0.6  ...      -0.60      -0.70
# 후행종합지수(2020=100)                4.1        4.2  ...     111.80     112.40
# 후행종합지수 전월비(%)                   2.5        2.4  ...       0.40       0.50
# 생산자제품재고지수(전월비)(%)               NaN        NaN  ...       0.90       0.70
# 소비자물가지수변화율(서비스)(전월차)(%p)        NaN        NaN  ...       0.00      -0.10
# 소비재수입액(전월비)(%)                  NaN        NaN  ...      -2.70      -2.30
# 취업자수(전월비)(%)                    NaN        NaN  ...       0.00      -0.10
# CP유통수익률(전월차)(%p)                NaN        NaN  ...       0.80       0.80
#
#                           2023.01 월  2023.02 월  2023.03 월  2023.04 월  \
# 지수별
# 선행종합지수(2020=100)             109.40     109.30     109.40     109.40
# 선행종합지수 전월비(%)                 -0.10      -0.10       0.10       0.00
# 재고순환지표(전월차)(%p)               -5.00      -0.80      -0.30      -0.30
# 경제심리지수(전월차)(p)                -1.80       0.10       0.00       1.20
# 기계류내수출하지수(선박제외)(전월비)(%)       -4.90      -3.20      -4.20      -1.60
# 건설수주액(전월비)(%)                 30.40       4.90      -4.20     -25.10
# 수출입물가비율(전월비)(%)               -0.10      -0.60      -0.20       0.10
# 코스피(전월비)(%)                    1.90       0.50       0.80       2.20
# 장단기금리차(전월차)(%p)               -0.39      -0.27      -0.11      -0.12
# 선행지수 순환변동치                    99.20      99.00      98.70      98.50
# 〔순환변동치 전월차〕(p)                -0.40      -0.20      -0.30      -0.20
# 선행지수 전년동월비(%)                  1.50       1.30       1.20       1.10
# 〔전년동월비 전월차〕(%p)               -0.30      -0.20      -0.10      -0.10
# 동행종합지수(2020=100)             108.20     108.70     109.50     110.00
# 동행종합지수 전월비(%)                 -0.20       0.50       0.70       0.50
# 광공업생산지수(전월비)(%)               -0.80      -1.40       1.30       0.40
# 서비스업생산지수(도소매업제외)(전월비)(%)      -0.10       1.00       0.30       0.80
# 건설기성액(전월비)(%)                  0.90       2.30       1.40       0.10
# 소매판매액지수(전월비)(%)               -1.30       1.30       1.10       0.80
# 내수출하지수(전월비)(%)                -0.20       0.00       0.40      -0.70
# 수입액(전월비)(%)                   -1.40       0.50       0.20      -0.20
# 비농림어업취업자수(전월비)(%)             -0.10       0.40       0.40       0.40
# 동행지수 순환변동치                    99.30      99.60     100.10     100.30
# 〔순환변동치 전월차〕(p)                -0.50       0.30       0.50       0.20
# 후행종합지수(2020=100)             112.80     112.90     113.10     113.40
# 후행종합지수 전월비(%)                  0.40       0.10       0.20       0.30
# 생산자제품재고지수(전월비)(%)              1.80       1.00       0.90       1.90
# 소비자물가지수변화율(서비스)(전월차)(%p)      -0.10      -0.10       0.00       0.00
# 소비재수입액(전월비)(%)                -0.10       0.10       0.90      -1.00
# 취업자수(전월비)(%)                  -0.10       0.20       0.40       0.40
# CP유통수익률(전월차)(%p)               0.30      -0.30      -0.50      -0.30
#
#                           2023.05 월  2023.06 월  2023.07 월  2023.08 월
# 지수별
# 선행종합지수(2020=100)              109.8     110.50     111.10     111.40
# 선행종합지수 전월비(%)                   0.4       0.60       0.50       0.30
# 재고순환지표(전월차)(%p)                -0.5       4.20       3.40       1.60
# 경제심리지수(전월차)(p)                  0.9       1.40       0.10      -0.10
# 기계류내수출하지수(선박제외)(전월비)(%)        -1.4      -0.90       0.40      -0.30
# 건설수주액(전월비)(%)                   0.2      13.00       2.90     -21.30
# 수출입물가비율(전월비)(%)                 0.9       0.80       0.70       0.10
# 코스피(전월비)(%)                     1.0       2.40       0.90       0.50
# 장단기금리차(전월차)(%p)                -0.1      -0.01       0.11       0.16
# 선행지수 순환변동치                     98.6      98.90      99.30      99.30
# 〔순환변동치 전월차〕(p)                  0.1       0.30       0.40       0.00
# 선행지수 전년동월비(%)                   1.2       1.60       2.10       2.20
# 〔전년동월비 전월차〕(%p)                 0.1       0.40       0.50       0.10
# 동행종합지수(2020=100)              110.3     110.30     110.00     110.10
# 동행종합지수 전월비(%)                   0.3       0.00      -0.30       0.10
# 광공업생산지수(전월비)(%)                 2.4       0.30      -0.20       0.60
# 서비스업생산지수(도소매업제외)(전월비)(%)       -0.4      -0.20      -0.10       0.50
# 건설기성액(전월비)(%)                  -0.8      -0.10      -0.20       1.00
# 소매판매액지수(전월비)(%)                -0.7      -0.40      -0.60      -0.90
# 내수출하지수(전월비)(%)                  0.3       0.10       0.20      -0.30
# 수입액(전월비)(%)                     1.4      -0.40      -3.10      -1.10
# 비농림어업취업자수(전월비)(%)               0.1       0.00      -0.10      -0.10
# 동행지수 순환변동치                    100.3     100.10      99.60      99.40
# 〔순환변동치 전월차〕(p)                  0.0      -0.20      -0.50      -0.20
# 후행종합지수(2020=100)              113.7     113.90     113.80     113.90
# 후행종합지수 전월비(%)                   0.3       0.20      -0.10       0.10
# 생산자제품재고지수(전월비)(%)               1.7       0.00      -1.30      -0.20
# 소비자물가지수변화율(서비스)(전월차)(%p)        0.0      -0.20      -0.30      -0.20
# 소비재수입액(전월비)(%)                 -2.1       1.90      -2.20      -1.10
# 취업자수(전월비)(%)                    0.2       0.00      -0.10      -0.10
# CP유통수익률(전월차)(%p)               -0.1       0.00       0.00       0.00
#
# [31 rows x 644 columns]

# %%
df = df.T
df
# Out:
# 지수별        선행종합지수(2020=100)  선행종합지수 전월비(%)  재고순환지표(전월차)(%p)  경제심리지수(전월차)(p)  \
# 1970.01 월               3.7            0.0              NaN             NaN
# 1970.02 월               3.7            0.0              NaN             NaN
# 1970.03 월               3.8            2.7              NaN             NaN
# 1970.04 월               3.8            0.0              NaN             NaN
# 1970.05 월               3.8            0.0              NaN             NaN
# ...                     ...            ...              ...             ...
# 2023.04 월             109.4            0.0             -0.3             1.2
# 2023.05 월             109.8            0.4             -0.5             0.9
# 2023.06 월             110.5            0.6              4.2             1.4
# 2023.07 월             111.1            0.5              3.4             0.1
# 2023.08 월             111.4            0.3              1.6            -0.1
#
# 지수별        기계류내수출하지수(선박제외)(전월비)(%)  건설수주액(전월비)(%)  수출입물가비율(전월비)(%)  \
# 1970.01 월                      NaN            NaN              NaN
# 1970.02 월                      NaN            NaN              NaN
# 1970.03 월                      NaN            NaN              NaN
# 1970.04 월                      NaN            NaN              NaN
# 1970.05 월                      NaN            NaN              NaN
# ...                            ...            ...              ...
# 2023.04 월                     -1.6          -25.1              0.1
# 2023.05 월                     -1.4            0.2              0.9
# 2023.06 월                     -0.9           13.0              0.8
# 2023.07 월                      0.4            2.9              0.7
# 2023.08 월                     -0.3          -21.3              0.1
#
# 지수별        코스피(전월비)(%)  장단기금리차(전월차)(%p)  선행지수 순환변동치  ...  비농림어업취업자수(전월비)(%)  \
# 1970.01 월          NaN              NaN       101.0  ...                NaN
# 1970.02 월          NaN              NaN       100.9  ...                NaN
# 1970.03 월          NaN              NaN       100.8  ...                NaN
# 1970.04 월          NaN              NaN       100.6  ...                NaN
# 1970.05 월          NaN              NaN       100.5  ...                NaN
# ...                ...              ...         ...  ...                ...
# 2023.04 월          2.2            -0.12        98.5  ...                0.4
# 2023.05 월          1.0            -0.10        98.6  ...                0.1
# 2023.06 월          2.4            -0.01        98.9  ...                0.0
# 2023.07 월          0.9             0.11        99.3  ...               -0.1
# 2023.08 월          0.5             0.16        99.3  ...               -0.1
#
# 지수별        동행지수 순환변동치  〔순환변동치 전월차〕(p)  후행종합지수(2020=100)  후행종합지수 전월비(%)  \
# 1970.01 월       100.6             0.0               3.6            0.0
# 1970.02 월       101.5             0.9               3.6            0.0
# 1970.03 월       101.9             0.4               3.8            5.6
# 1970.04 월       103.2             1.3               3.8            0.0
# 1970.05 월       103.2             0.0               3.8            0.0
# ...               ...             ...               ...            ...
# 2023.04 월       100.3             0.2             113.4            0.3
# 2023.05 월       100.3             0.0             113.7            0.3
# 2023.06 월       100.1            -0.2             113.9            0.2
# 2023.07 월        99.6            -0.5             113.8           -0.1
# 2023.08 월        99.4            -0.2             113.9            0.1
#
# 지수별        생산자제품재고지수(전월비)(%)  소비자물가지수변화율(서비스)(전월차)(%p)  소비재수입액(전월비)(%)  \
# 1970.01 월                NaN                       NaN             NaN
# 1970.02 월                NaN                       NaN             NaN
# 1970.03 월                NaN                       NaN             NaN
# 1970.04 월                NaN                       NaN             NaN
# 1970.05 월                NaN                       NaN             NaN
# ...                      ...                       ...             ...
# 2023.04 월                1.9                       0.0            -1.0
# 2023.05 월                1.7                       0.0            -2.1
# 2023.06 월                0.0                      -0.2             1.9
# 2023.07 월               -1.3                      -0.3            -2.2
# 2023.08 월               -0.2                      -0.2            -1.1
#
# 지수별        취업자수(전월비)(%)  CP유통수익률(전월차)(%p)
# 1970.01 월           NaN               NaN
# 1970.02 월           NaN               NaN
# 1970.03 월           NaN               NaN
# 1970.04 월           NaN               NaN
# 1970.05 월           NaN               NaN
# ...                 ...               ...
# 2023.04 월           0.4              -0.3
# 2023.05 월           0.2              -0.1
# 2023.06 월           0.0               0.0
# 2023.07 월          -0.1               0.0
# 2023.08 월          -0.1               0.0
#
# [644 rows x 31 columns]

# %%
df.head(1)
# Out:
# 지수별        선행종합지수(2020=100)  선행종합지수 전월비(%)  재고순환지표(전월차)(%p)  경제심리지수(전월차)(p)  \
# 1970.01 월               3.7            0.0              NaN             NaN
#
# 지수별        기계류내수출하지수(선박제외)(전월비)(%)  건설수주액(전월비)(%)  수출입물가비율(전월비)(%)  \
# 1970.01 월                      NaN            NaN              NaN
#
# 지수별        코스피(전월비)(%)  장단기금리차(전월차)(%p)  선행지수 순환변동치  ...  비농림어업취업자수(전월비)(%)  \
# 1970.01 월          NaN              NaN       101.0  ...                NaN
#
# 지수별        동행지수 순환변동치  〔순환변동치 전월차〕(p)  후행종합지수(2020=100)  후행종합지수 전월비(%)  \
# 1970.01 월       100.6             0.0               3.6            0.0
#
# 지수별        생산자제품재고지수(전월비)(%)  소비자물가지수변화율(서비스)(전월차)(%p)  소비재수입액(전월비)(%)  \
# 1970.01 월                NaN                       NaN             NaN
#
# 지수별        취업자수(전월비)(%)  CP유통수익률(전월차)(%p)
# 1970.01 월           NaN               NaN
#
# [1 rows x 31 columns]

# %%
df.tail(1)
# Out:
# 지수별        선행종합지수(2020=100)  선행종합지수 전월비(%)  재고순환지표(전월차)(%p)  경제심리지수(전월차)(p)  \
# 2023.08 월             111.4            0.3              1.6            -0.1
#
# 지수별        기계류내수출하지수(선박제외)(전월비)(%)  건설수주액(전월비)(%)  수출입물가비율(전월비)(%)  \
# 2023.08 월                     -0.3          -21.3              0.1
#
# 지수별        코스피(전월비)(%)  장단기금리차(전월차)(%p)  선행지수 순환변동치  ...  비농림어업취업자수(전월비)(%)  \
# 2023.08 월          0.5             0.16        99.3  ...               -0.1
#
# 지수별        동행지수 순환변동치  〔순환변동치 전월차〕(p)  후행종합지수(2020=100)  후행종합지수 전월비(%)  \
# 2023.08 월        99.4            -0.2             113.9            0.1
#
# 지수별        생산자제품재고지수(전월비)(%)  소비자물가지수변화율(서비스)(전월차)(%p)  소비재수입액(전월비)(%)  \
# 2023.08 월               -0.2                      -0.2            -1.1
#
# 지수별        취업자수(전월비)(%)  CP유통수익률(전월차)(%p)
# 2023.08 월          -0.1               0.0
#
# [1 rows x 31 columns]

# %%
df.index.name = '시점'

# %%
df.index.name
# Out:
# '시점'

# %%
df.columns.name
# Out:
# '지수별'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 644 entries, 1970.01 월 to 2023.08 월
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   선행종합지수(2020=100)          644 non-null    float64
#  1   선행종합지수 전월비(%)             644 non-null    float64
#  2   재고순환지표(전월차)(%p)           248 non-null    float64
#  3   경제심리지수(전월차)(p)            248 non-null    float64
#  4   기계류내수출하지수(선박제외)(전월비)(%)   248 non-null    float64
#  5   건설수주액(전월비)(%)             248 non-null    float64
#  6   수출입물가비율(전월비)(%)           248 non-null    float64
#  7   코스피(전월비)(%)               248 non-null    float64
#  8   장단기금리차(전월차)(%p)           248 non-null    float64
#  9   선행지수 순환변동치                644 non-null    float64
#  10  〔순환변동치 전월차〕(p)            644 non-null    float64
#  11  선행지수 전년동월비(%)             644 non-null    float64
#  12  〔전년동월비 전월차〕(%p)           644 non-null    float64
#  13  동행종합지수(2020=100)          644 non-null    float64
#  14  동행종합지수 전월비(%)             644 non-null    float64
#  15  광공업생산지수(전월비)(%)           248 non-null    float64
#  16  서비스업생산지수(도소매업제외)(전월비)(%)  248 non-null    float64
#  17  건설기성액(전월비)(%)             248 non-null    float64
#  18  소매판매액지수(전월비)(%)           248 non-null    float64
#  19  내수출하지수(전월비)(%)            248 non-null    float64
#  20  수입액(전월비)(%)               248 non-null    float64
#  21  비농림어업취업자수(전월비)(%)         248 non-null    float64
#  22  동행지수 순환변동치                644 non-null    float64
#  23  〔순환변동치 전월차〕(p)            644 non-null    float64
#  24  후행종합지수(2020=100)          644 non-null    float64
#  25  후행종합지수 전월비(%)             644 non-null    float64
#  26  생산자제품재고지수(전월비)(%)         248 non-null    float64
#  27  소비자물가지수변화율(서비스)(전월차)(%p)  248 non-null    float64
#  28  소비재수입액(전월비)(%)            248 non-null    float64
#  29  취업자수(전월비)(%)              248 non-null    float64
#  30  CP유통수익률(전월차)(%p)          248 non-null    float64
# dtypes: float64(31)
# memory usage: 177.2+ KB

# %%
df.describe()
# Out:
# 지수별    선행종합지수(2020=100)  선행종합지수 전월비(%)  재고순환지표(전월차)(%p)  경제심리지수(전월차)(p)  \
# count        644.000000     644.000000       248.000000      248.000000
# mean          43.921429       0.534006        -0.028629       -0.026613
# std           32.301838       0.663144         2.536253        2.559371
# min            3.700000      -2.300000        -8.600000      -12.200000
# 25%           13.475000       0.100000        -1.500000       -1.100000
# 50%           37.700000       0.400000        -0.100000        0.000000
# 75%           70.700000       0.800000         1.600000        1.000000
# max          111.400000       4.200000         7.300000        8.500000
#
# 지수별    기계류내수출하지수(선박제외)(전월비)(%)  건설수주액(전월비)(%)  수출입물가비율(전월비)(%)  코스피(전월비)(%)  \
# count               248.000000     248.000000       248.000000   248.000000
# mean                  0.054839       0.493548        -0.211694     0.629839
# std                   1.688463       9.278099         0.924467     2.962546
# min                  -6.500000     -27.200000        -2.200000   -11.100000
# 25%                  -0.900000      -5.225000        -0.800000    -1.200000
# 50%                   0.050000       0.300000        -0.200000     0.800000
# 75%                   1.000000       5.600000         0.300000     2.300000
# max                   4.600000      30.400000         3.400000     9.600000
#
# 지수별    장단기금리차(전월차)(%p)  선행지수 순환변동치  ...  비농림어업취업자수(전월비)(%)  동행지수 순환변동치  \
# count       248.000000  644.000000  ...         248.000000  644.000000
# mean         -0.003629  100.287422  ...           0.113710  100.261957
# std           0.134966    2.278627  ...           0.214206    1.940426
# min          -0.390000   91.800000  ...          -1.200000   93.000000
# 25%          -0.092500   99.300000  ...           0.000000   99.200000
# 50%          -0.010000  100.200000  ...           0.100000  100.100000
# 75%           0.060000  101.000000  ...           0.200000  101.300000
# max           0.560000  110.500000  ...           1.000000  106.100000
#
# 지수별    〔순환변동치 전월차〕(p)  후행종합지수(2020=100)  후행종합지수 전월비(%)  생산자제품재고지수(전월비)(%)  \
# count      644.000000        644.000000     644.000000         248.000000
# mean        -0.001863         45.723913       0.538665           0.426613
# std          0.454830         32.853593       0.682083           1.082553
# min         -2.100000          3.600000      -2.300000          -4.600000
# 25%         -0.200000         13.675000       0.200000          -0.200000
# 50%          0.000000         44.600000       0.400000           0.400000
# 75%          0.300000         71.850000       0.800000           1.025000
# max          1.400000        113.900000       5.600000           3.600000
#
# 지수별    소비자물가지수변화율(서비스)(전월차)(%p)  소비재수입액(전월비)(%)  취업자수(전월비)(%)  \
# count                248.000000      248.000000    248.000000
# mean                   0.000403        0.562500      0.095161
# std                    0.136319        1.967675      0.217030
# min                   -0.500000       -7.300000     -1.200000
# 25%                   -0.100000       -0.400000      0.000000
# 50%                    0.000000        0.650000      0.100000
# 75%                    0.100000        1.800000      0.200000
# max                    0.600000        5.600000      0.800000
#
# 지수별    CP유통수익률(전월차)(%p)
# count        248.000000
# mean          -0.000403
# std            0.186703
# min           -1.300000
# 25%            0.000000
# 50%            0.000000
# 75%            0.100000
# max            0.800000
#
# [8 rows x 31 columns]

# %% [markdown]
# # 데이터 탐색 및 요약

# %%
df.head()  # 데이터프레임의 처음 5개 행 확인
# Out:
#           선행종합지수(2020=100)  재고순환지표(%p)  경제심리지수  기계류내수출하지수(선박제외)(2020=100)  \
# 시점
# 1970.01                3.7           -       -                          -
# 1970.02                3.7           -       -                          -
# 1970.03                3.8           -       -                          -
# 1970.04                3.8           -       -                          -
# 1970.05                3.8           -       -                          -
#
#          건설수주액(실질)(십억원) 수출입물가비율(2015=100) 코스피(1980.1.4=100)  장단기금리차(%p)  \
# 시점
# 1970.01               -                 -                 -           -
# 1970.02               -                 -                 -           -
# 1970.03               -                 -                 -           -
# 1970.04               -                 -                 -           -
# 1970.05               -                 -                 -           -
#
#           동행종합지수(2020=100)  광공업생산지수(2020=100)  ...  소매판매액지수(2020=100)  \
# 시점                                             ...
# 1970.01                3.6                  -  ...                  -
# 1970.02                3.7                  -  ...                  -
# 1970.03                3.8                  -  ...                  -
# 1970.04                3.8                  -  ...                  -
# 1970.05                3.9                  -  ...                  -
#
#          내수출하지수(2020=100)  수입액(실질)(백만불)  비농림어업취업자수(천명)  후행종합지수(2020=100)  \
# 시점
# 1970.01                 -             -              -               3.6
# 1970.02                 -             -              -               3.6
# 1970.03                 -             -              -               3.8
# 1970.04                 -             -              -               3.8
# 1970.05                 -             -              -               3.8
#
#          생산자제품재고지수(2020=100)   소비자물가지수변화율(서비스)  소비재수입액(실질)(백만불)  취업자수(천명)  \
# 시점
# 1970.01                    -                 -                -         -
# 1970.02                    -                 -                -         -
# 1970.03                    -                 -                -         -
# 1970.04                    -                 -                -         -
# 1970.05                    -                 -                -         -
#
#          CP유통수익률(%p)
# 시점
# 1970.01            -
# 1970.02            -
# 1970.03            -
# 1970.04            -
# 1970.05            -
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#              선행종합지수(2020=100)  재고순환지표(%p)  경제심리지수  기계류내수출하지수(선박제외)(2020=100)  \
# 시점
# 2023.04                 109.4       -16.8    92.3                      101.3
# 2023.05                 109.8       -17.2    93.2                       99.9
# 2023.06 p)              110.5       -13.0    94.6                       99.0
# 2023.07 p)              111.1        -9.7    94.7                       99.4
# 2023.08 p)              111.4        -8.0    94.6                       99.1
#
#             건설수주액(실질)(십억원) 수출입물가비율(2015=100) 코스피(1980.1.4=100)  장단기금리차(%p)  \
# 시점
# 2023.04            10440.7              84.5            2463.7       -0.05
# 2023.05            10466.3              85.3            2488.4       -0.15
# 2023.06 p)         11826.5              86.0            2548.9       -0.16
# 2023.07 p)         12164.4              86.6            2572.6       -0.04
# 2023.08 p)          9575.8              86.7            2585.1        0.12
#
#              동행종합지수(2020=100)  광공업생산지수(2020=100)  ...  소매판매액지수(2020=100)  \
# 시점                                                ...
# 2023.04                 110.0              102.0  ...              106.6
# 2023.05                 110.3              104.4  ...              105.9
# 2023.06 p)              110.3              104.7  ...              105.5
# 2023.07 p)              110.0              104.5  ...              104.9
# 2023.08 p)              110.1              105.1  ...              104.0
#
#             내수출하지수(2020=100)  수입액(실질)(백만불)  비농림어업취업자수(천명)  후행종합지수(2020=100)  \
# 시점
# 2023.04                 96.4       47099.3        26928.9             113.4
# 2023.05                 96.7       47767.2        26948.0             113.7
# 2023.06 p)              96.8       47567.9        26946.1             113.9
# 2023.07 p)              97.0       46111.8        26930.2             113.8
# 2023.08 p)              96.7       45625.2        26915.3             113.9
#
#             생산자제품재고지수(2020=100)   소비자물가지수변화율(서비스)  소비재수입액(실질)(백만불)  취업자수(천명)  \
# 시점
# 2023.04                   120.1               3.9           9575.2   28420.3
# 2023.05                   122.2               3.8           9376.7   28466.5
# 2023.06 p)                122.2               3.6           9554.3   28465.4
# 2023.07 p)                120.6               3.3           9348.5   28447.9
# 2023.08 p)                120.3               3.1           9242.2   28425.6
#
#             CP유통수익률(%p)
# 시점
# 2023.04             4.1
# 2023.05             4.0
# 2023.06 p)          4.0
# 2023.07 p)          4.0
# 2023.08 p)          4.0
#
# [5 rows x 22 columns]

# %%
df.info()  # 데이터프레임의 정보(데이터 타입, 결측치 등) 출력
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 644 entries, 1970.01 to 2023.08 p)
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0    선행종합지수(2020=100)            644 non-null    float64
#  1    재고순환지표(%p)                  644 non-null    object
#  2    경제심리지수                      644 non-null    object
#  3    기계류내수출하지수(선박제외)(2020=100)   644 non-null    object
#  4    건설수주액(실질)(십억원)              644 non-null    object
#  5   수출입물가비율(2015=100)            644 non-null    object
#  6   코스피(1980.1.4=100)            644 non-null    object
#  7    장단기금리차(%p)                  644 non-null    object
#  8    동행종합지수(2020=100)            644 non-null    float64
#  9    광공업생산지수(2020=100)           644 non-null    object
#  10   서비스업생산지수(도소매업제외)(2020=100)  644 non-null    object
#  11   건설기성액(실질)(십억원)              644 non-null    object
#  12   소매판매액지수(2020=100)           644 non-null    object
#  13   내수출하지수(2020=100)            644 non-null    object
#  14   수입액(실질)(백만불)                644 non-null    object
#  15   비농림어업취업자수(천명)               644 non-null    object
#  16   후행종합지수(2020=100)            644 non-null    float64
#  17   생산자제품재고지수(2020=100)         644 non-null    object
#  18   소비자물가지수변화율(서비스)             644 non-null    object
#  19   소비재수입액(실질)(백만불)             644 non-null    object
#  20   취업자수(천명)                    644 non-null    object
#  21   CP유통수익률(%p)                 644 non-null    object
# dtypes: float64(3), object(19)
# memory usage: 115.7+ KB

# %%
# 데이터 전처리 (예시: 결측치 처리)
df.dropna(inplace=True)  # 결측치가 있는 행 제거

# %%
# 기초 통계 분석
df.describe()  # 데이터프레임의 기초 통계 정보 출력
# Out:
#         선행종합지수(2020=100)   동행종합지수(2020=100)   후행종합지수(2020=100)
# count         644.000000         644.000000         644.000000
# mean           43.921429          45.904658          45.723913
# std            32.301838          33.440069          32.853593
# min             3.700000           3.600000           3.600000
# 25%            13.475000          13.875000          13.675000
# 50%            37.700000          38.850000          44.600000
# 75%            70.700000          75.200000          71.850000
# max           111.400000         110.300000         113.900000

# %% [markdown]
# |        |  재고순환지표(%p)   |  경제심리지수   |  기계류내수출하지수(선박제외)(2020=100)   |  건설수주액(실질)(십억원)   | 수출입물가비율(2015=100)   | 코스피(1980.1.4=100)   |  장단기금리차(%p)   |  광공업생산지수(2020=100)   |  서비스업생산지수(도소매업제외)(2020=100)   |  건설기성액(실질)(십억원)   |  소매판매액지수(2020=100)   |  내수출하지수(2020=100)   |  수입액(실질)(백만불)   |  비농림어업취업자수(천명)   |  생산자제품재고지수(2020=100)   |  소비자물가지수변화율(서비스)   |  소비재수입액(실질)(백만불)   |  취업자수(천명)   |  CP유통수익률(%p)   |
# |:-------|:--------------------|:----------------|:------------------------------------------|:----------------------------|:---------------------------|:-----------------------|:--------------------|:----------------------------|:--------------------------------------------|:----------------------------|:----------------------------|:--------------------------|:------------------------|:----------------------------|:--------------------------------|:--------------------------------|:------------------------------|:------------------|:--------------------|
# | count  | 644                 | 644             | 644                                       | 644                         | 644                        | 644                    | 644                 | 644                         | 644                                         | 644                         | 644                         | 644                       | 644                     | 644                         | 644                             | 644                             | 644                           | 644               | 644                 |
# | unique | 159                 | 164             | 173                                       | 249                         | 187                        | 247                    | 144                 | 191                         | 198                                         | 249                         | 182                         | 153                       | 249                     | 248                         | 200                             | 42                              | 249                           | 248               | 52                  |
# | top    | -                   | -               | -                                         | -                           | -                          | -                      | -                   | -                           | -                                           | -                           | -                           | -                         | -                       | -                           | -                               | -                               | -                             | -                 | -                   |
# | freq   | 396                 | 396             | 396                                       | 396                         | 396                        | 396                    | 396                 | 396                         | 396                                         | 396                         | 396                         | 396                       | 396                     | 396                         | 396                             | 396                             | 396                           | 396               | 396                 |

# %%
# print(df.describe(exclude="number").to_markdown())

# %% [markdown]
# ## 데이터 전처리

# %%
obj_cols = df.describe(exclude="number").columns
obj_cols
# Out:
# Index([' 재고순환지표(%p)', ' 경제심리지수', ' 기계류내수출하지수(선박제외)(2020=100)',
#        ' 건설수주액(실질)(십억원)', '수출입물가비율(2015=100)', '코스피(1980.1.4=100)',
#        ' 장단기금리차(%p)', ' 광공업생산지수(2020=100)', ' 서비스업생산지수(도소매업제외)(2020=100)',
#        ' 건설기성액(실질)(십억원)', ' 소매판매액지수(2020=100)', ' 내수출하지수(2020=100)',
#        ' 수입액(실질)(백만불)', ' 비농림어업취업자수(천명)', ' 생산자제품재고지수(2020=100)',
#        ' 소비자물가지수변화율(서비스)', ' 소비재수입액(실질)(백만불)', ' 취업자수(천명)', ' CP유통수익률(%p)'],
#       dtype='object')

# %%
# "-" 값을 NaN으로 처리하고 숫자형으로 변환할 열의 리스트
# 각 열에 대해 "-" 값을 NaN으로 처리하고 숫자형으로 변환
for column in obj_cols:
    df[column] = pd.to_numeric(df[column], errors='coerce')

# 데이터프레임에서 결측치를 제거하거나 다른 방식으로 처리할 수도 있습니다.
# 예를 들어, 결측치를 평균값이나 중간값으로 대체할 수 있습니다:
# df.fillna(df.mean(), inplace=True)  # 결측치를 평균값으로 대체

# 데이터프레임의 정보를 다시 확인하여 데이터 타입 및 결측치 처리 상황을 확인하세요
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 644 entries, 1970.01 to 2023.08 p)
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0    선행종합지수(2020=100)            644 non-null    float64
#  1    재고순환지표(%p)                  248 non-null    float64
#  2    경제심리지수                      248 non-null    float64
#  3    기계류내수출하지수(선박제외)(2020=100)   248 non-null    float64
#  4    건설수주액(실질)(십억원)              248 non-null    float64
#  5   수출입물가비율(2015=100)            248 non-null    float64
#  6   코스피(1980.1.4=100)            248 non-null    float64
#  7    장단기금리차(%p)                  248 non-null    float64
#  8    동행종합지수(2020=100)            644 non-null    float64
#  9    광공업생산지수(2020=100)           248 non-null    float64
#  10   서비스업생산지수(도소매업제외)(2020=100)  248 non-null    float64
#  11   건설기성액(실질)(십억원)              248 non-null    float64
#  12   소매판매액지수(2020=100)           248 non-null    float64
#  13   내수출하지수(2020=100)            248 non-null    float64
#  14   수입액(실질)(백만불)                248 non-null    float64
#  15   비농림어업취업자수(천명)               248 non-null    float64
#  16   후행종합지수(2020=100)            644 non-null    float64
#  17   생산자제품재고지수(2020=100)         248 non-null    float64
#  18   소비자물가지수변화율(서비스)             248 non-null    float64
#  19   소비재수입액(실질)(백만불)             248 non-null    float64
#  20   취업자수(천명)                    248 non-null    float64
#  21   CP유통수익률(%p)                 248 non-null    float64
# dtypes: float64(22)
# memory usage: 115.7+ KB

# %%
sns.heatmap(df.isnull().T)
# Out:
# <Axes: xlabel='시점', ylabel='지수별'>

# %%
# df.describe().T.to_markdown()
df.describe()
# Out:
#         선행종합지수(2020=100)   재고순환지표(%p)      경제심리지수   기계류내수출하지수(선박제외)(2020=100)  \
# count         644.000000   248.000000  248.000000                  248.000000
# mean           43.921429    -2.350806   99.808871                   99.913306
# std            32.301838     7.772650    9.525164                   10.161877
# min             3.700000   -24.900000   64.300000                   79.700000
# 25%            13.475000    -6.350000   95.250000                   94.400000
# 50%            37.700000    -3.700000   99.400000                  100.200000
# 75%            70.700000     1.225000  105.725000                  107.525000
# max           111.400000    31.300000  116.400000                  119.500000
#
#         건설수주액(실질)(십억원)  수출입물가비율(2015=100)  코스피(1980.1.4=100)   장단기금리차(%p)  \
# count       248.000000         248.000000         248.000000   248.000000
# mean      10127.162097         103.078226        1854.819758     0.791411
# std        3008.851557          18.793702         585.160043     0.690946
# min        5315.300000          83.600000         576.100000    -0.250000
# 25%        7614.600000          89.075000        1473.575000     0.307500
# 50%        9478.750000          97.700000        1957.950000     0.660000
# 75%       12101.475000         106.600000        2129.250000     1.090000
# max       17798.000000         151.600000        3232.100000     2.900000
#
#         동행종합지수(2020=100)   광공업생산지수(2020=100)  ...   소매판매액지수(2020=100)  \
# count         644.000000          248.000000  ...          248.000000
# mean           45.904658           86.802823  ...           83.925403
# std            33.440069           16.729250  ...           14.523956
# min             3.600000           51.600000  ...           60.300000
# 25%            13.875000           72.500000  ...           70.700000
# 50%            38.850000           93.300000  ...           83.950000
# 75%            75.200000           98.850000  ...           97.700000
# max           110.300000          114.400000  ...          107.500000
#
#         내수출하지수(2020=100)   수입액(실질)(백만불)   비농림어업취업자수(천명)   후행종합지수(2020=100)  \
# count         248.000000     248.000000      248.000000         644.000000
# mean           91.674194   32996.229032    23626.844355          45.723913
# std            10.010406    7764.241814     1985.467038          32.853593
# min            70.600000   20166.800000    20122.700000           3.600000
# 25%            84.050000   26568.150000    21956.425000          13.675000
# 50%            95.700000   32242.450000    23613.950000          44.600000
# 75%            99.525000   39571.375000    25437.875000          71.850000
# max           103.900000   49383.700000    26948.000000         113.900000
#
#         생산자제품재고지수(2020=100)   소비자물가지수변화율(서비스)   소비재수입액(실질)(백만불)      취업자수(천명)  \
# count            248.000000        248.000000        248.000000    248.000000
# mean              77.549194          2.265323       5074.077823  25189.947177
# std               21.058871          0.951116       2185.929527   1815.404601
# min               42.200000          0.100000       2269.300000  22131.200000
# 25%               57.275000          1.600000       3122.350000  23636.925000
# 50%               79.800000          2.100000       4614.900000  25116.400000
# 75%               95.300000          2.900000       6764.975000  26777.175000
# max              122.200000          4.200000      10087.600000  28466.500000
#
#         CP유통수익률(%p)
# count    248.000000
# mean       3.111290
# std        1.415771
# min        1.000000
# 25%        1.800000
# 50%        2.900000
# 75%        4.100000
# max        7.100000
#
# [8 rows x 22 columns]

# %%
df.hist(figsize=(12, 10), bins=50);

# %%
# 전체 데이터프레임을 사용할 경우:
# df: 전체 데이터프레임
# sns.pairplot(df)
# plt.show()

# 일부 변수만 사용할 경우 (예: 처음 6개 변수):
selected_columns = df.iloc[:, :6]  # 데이터프레임에서 원하는 변수 선택
sns.pairplot(selected_columns)

# %%
# sns.pairplot?

# %%
sns.pairplot(df.iloc[:, 6:12], kind="reg")

# %% [markdown]
# ## 상관 관계
#
# * 상관 계수 값: 상관 계수는 -1부터 1까지의 값을 가지며, 0에 가까울수록 두 변수 간의 선형 관계가 약하거나 없음을 의미합니다. 양수 값은 양의 상관 관계(한 변수가 증가하면 다른 변수도 증가)를 의미하고, 음수 값은 음의 상관 관계(한 변수가 증가하면 다른 변수는 감소)를 의미합니다.
#
# * 강도: 상관 계수의 절대값이 클수록 두 변수 간의 선형 관계가 강력하다고 볼 수 있습니다. 일반적으로 0.7 이상의 상관 계수는 강력한 상관 관계를 나타냅니다.
#
# * 방향: 상관 계수의 부호는 두 변수 간의 관계의 방향을 나타냅니다. 양의 상관 관계는 두 변수가 동시에 증가하거나 감소하는 경향이 있음을 의미하고, 음의 상관 관계는 한 변수가 증가하면 다른 변수는 감소하는 경향이 있음을 의미합니다.

# %%
corr = df.corr()
mask = np.triu(np.ones_like(corr))

# %%
# print(corr.to_markdown())

# %%
corr
# Out:
# 지수별                       선행종합지수(2020=100)  선행종합지수 전월비(%)  재고순환지표(전월차)(%p)  \
# 지수별
# 선행종합지수(2020=100)                  1.000000      -0.302747        -0.013144
# 선행종합지수 전월비(%)                    -0.302747       1.000000         0.637567
# 재고순환지표(전월차)(%p)                  -0.013144       0.637567         1.000000
# 경제심리지수(전월차)(p)                    0.005033       0.628244         0.372656
# 기계류내수출하지수(선박제외)(전월비)(%)          -0.030960       0.488802         0.269450
# 건설수주액(전월비)(%)                    -0.010414       0.327962         0.011242
# 수출입물가비율(전월비)(%)                   0.134190       0.043654        -0.072803
# 코스피(전월비)(%)                      -0.141255       0.579350         0.293686
# 장단기금리차(전월차)(%p)                  -0.031328       0.436153         0.272562
# 선행지수 순환변동치                       -0.074718       0.074089        -0.022046
# 〔순환변동치 전월차〕(p)                    0.000474       0.772887         0.636801
# 선행지수 전년동월비(%)                    -0.467609       0.425243         0.080386
# 〔전년동월비 전월차〕(%p)                  -0.029291       0.606439         0.666467
# 동행종합지수(2020=100)                  0.997857      -0.313772        -0.018549
# 동행종합지수 전월비(%)                    -0.353801       0.376336         0.302734
# 광공업생산지수(전월비)(%)                  -0.138156       0.471704         0.358731
# 서비스업생산지수(도소매업제외)(전월비)(%)         -0.028003       0.251307         0.151288
# 건설기성액(전월비)(%)                     0.029092       0.210464         0.175842
# 소매판매액지수(전월비)(%)                  -0.025730       0.276621         0.221370
# 내수출하지수(전월비)(%)                   -0.091304       0.490612         0.446606
# 수입액(전월비)(%)                      -0.027846       0.049609         0.002441
# 비농림어업취업자수(전월비)(%)                -0.052982       0.181421         0.061460
# 동행지수 순환변동치                       -0.106548      -0.293240        -0.150780
# 〔순환변동치 전월차〕(p)                    0.005540       0.267148         0.324332
# 후행종합지수(2020=100)                  0.997863      -0.315561        -0.016880
# 후행종합지수 전월비(%)                    -0.322788       0.121521        -0.311728
# 생산자제품재고지수(전월비)(%)                -0.039576      -0.428473        -0.598583
# 소비자물가지수변화율(서비스)(전월차)(%p)          0.094013      -0.243818        -0.258405
# 소비재수입액(전월비)(%)                    0.022973       0.257842         0.173798
# 취업자수(전월비)(%)                      0.017935       0.154402        -0.003121
# CP유통수익률(전월차)(%p)                  0.124798      -0.316784        -0.296448
#
# 지수별                       경제심리지수(전월차)(p)  기계류내수출하지수(선박제외)(전월비)(%)  \
# 지수별
# 선행종합지수(2020=100)                0.005033                -0.030960
# 선행종합지수 전월비(%)                   0.628244                 0.488802
# 재고순환지표(전월차)(%p)                 0.372656                 0.269450
# 경제심리지수(전월차)(p)                  1.000000                 0.251579
# 기계류내수출하지수(선박제외)(전월비)(%)         0.251579                 1.000000
# 건설수주액(전월비)(%)                   0.020762                 0.115810
# 수출입물가비율(전월비)(%)                -0.291808                -0.164262
# 코스피(전월비)(%)                     0.617581                 0.162508
# 장단기금리차(전월차)(%p)                 0.146694                 0.014823
# 선행지수 순환변동치                      0.295086                 0.357387
# 〔순환변동치 전월차〕(p)                  0.646862                 0.506313
# 선행지수 전년동월비(%)                   0.370983                 0.386525
# 〔전년동월비 전월차〕(%p)                 0.542123                 0.339777
# 동행종합지수(2020=100)               -0.018774                -0.039413
# 동행종합지수 전월비(%)                   0.533221                 0.411794
# 광공업생산지수(전월비)(%)                 0.601624                 0.412464
# 서비스업생산지수(도소매업제외)(전월비)(%)        0.507232                 0.135678
# 건설기성액(전월비)(%)                   0.142346                 0.127107
# 소매판매액지수(전월비)(%)                 0.248793                 0.148812
# 내수출하지수(전월비)(%)                  0.492668                 0.522544
# 수입액(전월비)(%)                     0.067666                 0.357478
# 비농림어업취업자수(전월비)(%)               0.433786                 0.087016
# 동행지수 순환변동치                     -0.128951                 0.049667
# 〔순환변동치 전월차〕(p)                  0.532072                 0.403472
# 후행종합지수(2020=100)               -0.023417                -0.057866
# 후행종합지수 전월비(%)                   0.053316                 0.131513
# 생산자제품재고지수(전월비)(%)              -0.117125                -0.030748
# 소비자물가지수변화율(서비스)(전월차)(%p)       -0.172291                -0.023491
# 소비재수입액(전월비)(%)                  0.232152                 0.306512
# 취업자수(전월비)(%)                    0.405894                 0.059393
# CP유통수익률(전월차)(%p)               -0.237425                 0.090869
#
# 지수별                       건설수주액(전월비)(%)  수출입물가비율(전월비)(%)  코스피(전월비)(%)  \
# 지수별
# 선행종합지수(2020=100)              -0.010414         0.134190    -0.141255
# 선행종합지수 전월비(%)                  0.327962         0.043654     0.579350
# 재고순환지표(전월차)(%p)                0.011242        -0.072803     0.293686
# 경제심리지수(전월차)(p)                 0.020762        -0.291808     0.617581
# 기계류내수출하지수(선박제외)(전월비)(%)        0.115810        -0.164262     0.162508
# 건설수주액(전월비)(%)                  1.000000         0.001393     0.045039
# 수출입물가비율(전월비)(%)                0.001393         1.000000    -0.341982
# 코스피(전월비)(%)                    0.045039        -0.341982     1.000000
# 장단기금리차(전월차)(%p)               -0.110607         0.001021     0.192209
# 선행지수 순환변동치                    -0.017451        -0.349583     0.238589
# 〔순환변동치 전월차〕(p)                 0.302388         0.031937     0.600602
# 선행지수 전년동월비(%)                  0.021493        -0.146807     0.295655
# 〔전년동월비 전월차〕(%p)                0.234699         0.090923     0.540891
# 동행종합지수(2020=100)              -0.009030         0.152803    -0.175901
# 동행종합지수 전월비(%)                  0.007642        -0.220727     0.302646
# 광공업생산지수(전월비)(%)               -0.075211        -0.246204     0.416694
# 서비스업생산지수(도소매업제외)(전월비)(%)       0.021024        -0.261133     0.251145
# 건설기성액(전월비)(%)                  0.049051         0.072934     0.064911
# 소매판매액지수(전월비)(%)                0.054041        -0.147896     0.228154
# 내수출하지수(전월비)(%)                -0.045080        -0.190520     0.347599
# 수입액(전월비)(%)                   -0.071076         0.039656    -0.062985
# 비농림어업취업자수(전월비)(%)              0.096990        -0.272328     0.207589
# 동행지수 순환변동치                    -0.086889        -0.225408    -0.229714
# 〔순환변동치 전월차〕(p)                 0.021369        -0.196860     0.283510
# 후행종합지수(2020=100)              -0.010946         0.160899    -0.169068
# 후행종합지수 전월비(%)                  0.028930        -0.257826    -0.015240
# 생산자제품재고지수(전월비)(%)             -0.057660        -0.160371    -0.128721
# 소비자물가지수변화율(서비스)(전월차)(%p)       0.002947        -0.062929    -0.152108
# 소비재수입액(전월비)(%)                 0.078571        -0.231777     0.229891
# 취업자수(전월비)(%)                   0.085756        -0.216800     0.166901
# CP유통수익률(전월차)(%p)              -0.051022        -0.027237    -0.232301
#
# 지수별                       장단기금리차(전월차)(%p)  선행지수 순환변동치  ...  비농림어업취업자수(전월비)(%)  \
# 지수별                                                    ...
# 선행종합지수(2020=100)                -0.031328   -0.074718  ...          -0.052982
# 선행종합지수 전월비(%)                    0.436153    0.074089  ...           0.181421
# 재고순환지표(전월차)(%p)                  0.272562   -0.022046  ...           0.061460
# 경제심리지수(전월차)(p)                   0.146694    0.295086  ...           0.433786
# 기계류내수출하지수(선박제외)(전월비)(%)          0.014823    0.357387  ...           0.087016
# 건설수주액(전월비)(%)                   -0.110607   -0.017451  ...           0.096990
# 수출입물가비율(전월비)(%)                  0.001021   -0.349583  ...          -0.272328
# 코스피(전월비)(%)                      0.192209    0.238589  ...           0.207589
# 장단기금리차(전월차)(%p)                  1.000000   -0.147954  ...          -0.045325
# 선행지수 순환변동치                      -0.147954    1.000000  ...           0.306289
# 〔순환변동치 전월차〕(p)                   0.424008    0.110328  ...           0.197042
# 선행지수 전년동월비(%)                    0.044685    0.608326  ...           0.173181
# 〔전년동월비 전월차〕(%p)                  0.460129   -0.229574  ...           0.122410
# 동행종합지수(2020=100)                -0.041943   -0.083350  ...          -0.051133
# 동행종합지수 전월비(%)                    0.050788    0.340700  ...           0.565675
# 광공업생산지수(전월비)(%)                  0.076928    0.324485  ...           0.186536
# 서비스업생산지수(도소매업제외)(전월비)(%)         0.036281    0.229180  ...           0.497219
# 건설기성액(전월비)(%)                    0.018782   -0.034010  ...           0.111003
# 소매판매액지수(전월비)(%)                  0.105937    0.178118  ...           0.150219
# 내수출하지수(전월비)(%)                   0.051213    0.317043  ...           0.160788
# 수입액(전월비)(%)                     -0.196727    0.366706  ...           0.117916
# 비농림어업취업자수(전월비)(%)               -0.045325    0.306289  ...           1.000000
# 동행지수 순환변동치                      -0.265151    0.525145  ...           0.271763
# 〔순환변동치 전월차〕(p)                   0.036944    0.424378  ...           0.550616
# 후행종합지수(2020=100)                -0.039496   -0.094120  ...          -0.060752
# 후행종합지수 전월비(%)                   -0.320276    0.280793  ...           0.382150
# 생산자제품재고지수(전월비)(%)               -0.359615    0.275524  ...           0.041544
# 소비자물가지수변화율(서비스)(전월차)(%p)        -0.201706    0.199633  ...           0.096864
# 소비재수입액(전월비)(%)                  -0.059131    0.324388  ...           0.219557
# 취업자수(전월비)(%)                    -0.048425    0.271389  ...           0.928906
# CP유통수익률(전월차)(%p)                -0.346777    0.249301  ...           0.013299
#
# 지수별                       동행지수 순환변동치  〔순환변동치 전월차〕(p)  후행종합지수(2020=100)  \
# 지수별
# 선행종합지수(2020=100)           -0.106548        0.005540          0.997863
# 선행종합지수 전월비(%)              -0.293240        0.267148         -0.315561
# 재고순환지표(전월차)(%p)            -0.150780        0.324332         -0.016880
# 경제심리지수(전월차)(p)             -0.128951        0.532072         -0.023417
# 기계류내수출하지수(선박제외)(전월비)(%)     0.049667        0.403472         -0.057866
# 건설수주액(전월비)(%)              -0.086889        0.021369         -0.010946
# 수출입물가비율(전월비)(%)            -0.225408       -0.196860          0.160899
# 코스피(전월비)(%)                -0.229714        0.283510         -0.169068
# 장단기금리차(전월차)(%p)            -0.265151        0.036944         -0.039496
# 선행지수 순환변동치                  0.525145        0.424378         -0.094120
# 〔순환변동치 전월차〕(p)             -0.364689        0.368627         -0.011062
# 선행지수 전년동월비(%)              -0.047299        0.334834         -0.494485
# 〔전년동월비 전월차〕(%p)            -0.395265        0.161665         -0.030056
# 동행종합지수(2020=100)           -0.095495       -0.000412          0.997496
# 동행종합지수 전월비(%)               0.070826        0.699836         -0.370803
# 광공업생산지수(전월비)(%)             0.004670        0.639959         -0.166667
# 서비스업생산지수(도소매업제외)(전월비)(%)    0.137546        0.514955         -0.040262
# 건설기성액(전월비)(%)              -0.027999        0.426165          0.036683
# 소매판매액지수(전월비)(%)            -0.091613        0.489744         -0.041944
# 내수출하지수(전월비)(%)             -0.037550        0.692895         -0.114291
# 수입액(전월비)(%)                 0.248779        0.434713         -0.049181
# 비농림어업취업자수(전월비)(%)           0.271763        0.550616         -0.060752
# 동행지수 순환변동치                  1.000000        0.117508         -0.096535
# 〔순환변동치 전월차〕(p)              0.117508        1.000000         -0.008636
# 후행종합지수(2020=100)           -0.096535       -0.008636          1.000000
# 후행종합지수 전월비(%)               0.248084        0.144859         -0.333333
# 생산자제품재고지수(전월비)(%)           0.278921       -0.001355         -0.043496
# 소비자물가지수변화율(서비스)(전월차)(%p)    0.168782        0.036097          0.080167
# 소비재수입액(전월비)(%)              0.112473        0.449581          0.003715
# 취업자수(전월비)(%)                0.285707        0.514302          0.010444
# CP유통수익률(전월차)(%p)            0.311554       -0.101326          0.120301
#
# 지수별                       후행종합지수 전월비(%)  생산자제품재고지수(전월비)(%)  \
# 지수별
# 선행종합지수(2020=100)              -0.322788          -0.039576
# 선행종합지수 전월비(%)                  0.121521          -0.428473
# 재고순환지표(전월차)(%p)               -0.311728          -0.598583
# 경제심리지수(전월차)(p)                 0.053316          -0.117125
# 기계류내수출하지수(선박제외)(전월비)(%)        0.131513          -0.030748
# 건설수주액(전월비)(%)                  0.028930          -0.057660
# 수출입물가비율(전월비)(%)               -0.257826          -0.160371
# 코스피(전월비)(%)                   -0.015240          -0.128721
# 장단기금리차(전월차)(%p)               -0.320276          -0.359615
# 선행지수 순환변동치                     0.280793           0.275524
# 〔순환변동치 전월차〕(p)                -0.024397          -0.411099
# 선행지수 전년동월비(%)                  0.246564           0.094219
# 〔전년동월비 전월차〕(%p)               -0.071865          -0.468525
# 동행종합지수(2020=100)              -0.327866          -0.042298
# 동행종합지수 전월비(%)                  0.207108           0.025993
# 광공업생산지수(전월비)(%)                0.030312           0.069034
# 서비스업생산지수(도소매업제외)(전월비)(%)       0.260867          -0.016584
# 건설기성액(전월비)(%)                  0.028560          -0.084322
# 소매판매액지수(전월비)(%)               -0.005138          -0.148213
# 내수출하지수(전월비)(%)                 0.034451          -0.019070
# 수입액(전월비)(%)                    0.344919           0.274688
# 비농림어업취업자수(전월비)(%)              0.382150           0.041544
# 동행지수 순환변동치                     0.248084           0.278921
# 〔순환변동치 전월차〕(p)                 0.144859          -0.001355
# 후행종합지수(2020=100)              -0.333333          -0.043496
# 후행종합지수 전월비(%)                  1.000000           0.546353
# 생산자제품재고지수(전월비)(%)              0.546353           1.000000
# 소비자물가지수변화율(서비스)(전월차)(%p)       0.584028           0.319814
# 소비재수입액(전월비)(%)                 0.415943           0.005488
# 취업자수(전월비)(%)                   0.397705           0.032085
# CP유통수익률(전월차)(%p)               0.533103           0.370426
#
# 지수별                       소비자물가지수변화율(서비스)(전월차)(%p)  소비재수입액(전월비)(%)  \
# 지수별
# 선행종합지수(2020=100)                          0.094013        0.022973
# 선행종합지수 전월비(%)                            -0.243818        0.257842
# 재고순환지표(전월차)(%p)                          -0.258405        0.173798
# 경제심리지수(전월차)(p)                           -0.172291        0.232152
# 기계류내수출하지수(선박제외)(전월비)(%)                  -0.023491        0.306512
# 건설수주액(전월비)(%)                             0.002947        0.078571
# 수출입물가비율(전월비)(%)                          -0.062929       -0.231777
# 코스피(전월비)(%)                              -0.152108        0.229891
# 장단기금리차(전월차)(%p)                          -0.201706       -0.059131
# 선행지수 순환변동치                                0.199633        0.324388
# 〔순환변동치 전월차〕(p)                           -0.261234        0.227906
# 선행지수 전년동월비(%)                             0.077721        0.232747
# 〔전년동월비 전월차〕(%p)                          -0.378543        0.154302
# 동행종합지수(2020=100)                          0.078982        0.021315
# 동행종합지수 전월비(%)                             0.019767        0.434822
# 광공업생산지수(전월비)(%)                          -0.158856        0.259421
# 서비스업생산지수(도소매업제외)(전월비)(%)                  0.109397        0.197903
# 건설기성액(전월비)(%)                            -0.063189        0.129294
# 소매판매액지수(전월비)(%)                          -0.053179        0.260374
# 내수출하지수(전월비)(%)                           -0.166538        0.350807
# 수입액(전월비)(%)                               0.168381        0.344111
# 비농림어업취업자수(전월비)(%)                         0.096864        0.219557
# 동행지수 순환변동치                                0.168782        0.112473
# 〔순환변동치 전월차〕(p)                            0.036097        0.449581
# 후행종합지수(2020=100)                          0.080167        0.003715
# 후행종합지수 전월비(%)                             0.584028        0.415943
# 생산자제품재고지수(전월비)(%)                         0.319814        0.005488
# 소비자물가지수변화율(서비스)(전월차)(%p)                  1.000000        0.051828
# 소비재수입액(전월비)(%)                            0.051828        1.000000
# 취업자수(전월비)(%)                              0.091752        0.208333
# CP유통수익률(전월차)(%p)                          0.319742        0.074016
#
# 지수별                       취업자수(전월비)(%)  CP유통수익률(전월차)(%p)
# 지수별
# 선행종합지수(2020=100)              0.017935          0.124798
# 선행종합지수 전월비(%)                 0.154402         -0.316784
# 재고순환지표(전월차)(%p)              -0.003121         -0.296448
# 경제심리지수(전월차)(p)                0.405894         -0.237425
# 기계류내수출하지수(선박제외)(전월비)(%)       0.059393          0.090869
# 건설수주액(전월비)(%)                 0.085756         -0.051022
# 수출입물가비율(전월비)(%)              -0.216800         -0.027237
# 코스피(전월비)(%)                   0.166901         -0.232301
# 장단기금리차(전월차)(%p)              -0.048425         -0.346777
# 선행지수 순환변동치                    0.271389          0.249301
# 〔순환변동치 전월차〕(p)                0.165199         -0.303266
# 선행지수 전년동월비(%)                 0.153842          0.047253
# 〔전년동월비 전월차〕(%p)               0.104758         -0.321595
# 동행종합지수(2020=100)              0.020440          0.119304
# 동행종합지수 전월비(%)                 0.510340         -0.105811
# 광공업생산지수(전월비)(%)               0.156851         -0.251322
# 서비스업생산지수(도소매업제외)(전월비)(%)      0.429818         -0.053289
# 건설기성액(전월비)(%)                 0.095914         -0.089832
# 소매판매액지수(전월비)(%)               0.088884         -0.189880
# 내수출하지수(전월비)(%)                0.133471         -0.152797
# 수입액(전월비)(%)                   0.121602          0.306994
# 비농림어업취업자수(전월비)(%)             0.928906          0.013299
# 동행지수 순환변동치                    0.285707          0.311554
# 〔순환변동치 전월차〕(p)                0.514302         -0.101326
# 후행종합지수(2020=100)              0.010444          0.120301
# 후행종합지수 전월비(%)                 0.397705          0.533103
# 생산자제품재고지수(전월비)(%)             0.032085          0.370426
# 소비자물가지수변화율(서비스)(전월차)(%p)      0.091752          0.319742
# 소비재수입액(전월비)(%)                0.208333          0.074016
# 취업자수(전월비)(%)                  1.000000          0.026929
# CP유통수익률(전월차)(%p)              0.026929          1.000000
#
# [31 rows x 31 columns]

# %%
corr.min().nsmallest(10)
# Out:
# 지수별
# 재고순환지표(전월차)(%p)     -0.598583
# 생산자제품재고지수(전월비)(%)   -0.598583
# 선행지수 전년동월비(%)       -0.494485
# 후행종합지수(2020=100)    -0.494485
# 동행종합지수(2020=100)    -0.485703
# 〔전년동월비 전월차〕(%p)     -0.468525
# 선행종합지수(2020=100)    -0.467609
# 선행종합지수 전월비(%)       -0.428473
# 〔순환변동치 전월차〕(p)      -0.411099
# 동행지수 순환변동치          -0.395265
# dtype: float64

# %%
corr.columns
# Out:
# Index(['선행종합지수(2020=100)', '선행종합지수 전월비(%)', '재고순환지표(전월차)(%p)',
#        '경제심리지수(전월차)(p)', '기계류내수출하지수(선박제외)(전월비)(%)', '건설수주액(전월비)(%)',
#        '수출입물가비율(전월비)(%)', '코스피(전월비)(%)', '장단기금리차(전월차)(%p)', '선행지수 순환변동치',
#        '〔순환변동치 전월차〕(p)', '선행지수 전년동월비(%)', '〔전년동월비 전월차〕(%p)',
#        '동행종합지수(2020=100)', '동행종합지수 전월비(%)', '광공업생산지수(전월비)(%)',
#        '서비스업생산지수(도소매업제외)(전월비)(%)', '건설기성액(전월비)(%)', '소매판매액지수(전월비)(%)',
#        '내수출하지수(전월비)(%)', '수입액(전월비)(%)', '비농림어업취업자수(전월비)(%)', '동행지수 순환변동치',
#        '〔순환변동치 전월차〕(p)', '후행종합지수(2020=100)', '후행종합지수 전월비(%)',
#        '생산자제품재고지수(전월비)(%)', '소비자물가지수변화율(서비스)(전월차)(%p)', '소비재수입액(전월비)(%)',
#        '취업자수(전월비)(%)', 'CP유통수익률(전월차)(%p)'],
#       dtype='object', name='지수별')

# %%
corr["수출입물가비율(전월비)(%)"].nsmallest(10)
# Out:
# 지수별
# 선행지수 순환변동치                 -0.349583
# 코스피(전월비)(%)                -0.341982
# 경제심리지수(전월차)(p)             -0.291808
# 비농림어업취업자수(전월비)(%)          -0.272328
# 서비스업생산지수(도소매업제외)(전월비)(%)   -0.261133
# 후행종합지수 전월비(%)              -0.257826
# 광공업생산지수(전월비)(%)            -0.246204
# 소비재수입액(전월비)(%)             -0.231777
# 동행지수 순환변동치                 -0.225408
# 동행종합지수 전월비(%)              -0.220727
# Name: 수출입물가비율(전월비)(%), dtype: float64

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", vmin=-1, vmax=1, mask=mask)
# Out:
# <Axes: xlabel='지수별', ylabel='지수별'>

# %%
df.columns
# Out:
# Index(['선행종합지수(2020=100)', '선행종합지수 전월비(%)', '재고순환지표(전월차)(%p)',
#        '경제심리지수(전월차)(p)', '기계류내수출하지수(선박제외)(전월비)(%)', '건설수주액(전월비)(%)',
#        '수출입물가비율(전월비)(%)', '코스피(전월비)(%)', '장단기금리차(전월차)(%p)', '선행지수 순환변동치',
#        '〔순환변동치 전월차〕(p)', '선행지수 전년동월비(%)', '〔전년동월비 전월차〕(%p)',
#        '동행종합지수(2020=100)', '동행종합지수 전월비(%)', '광공업생산지수(전월비)(%)',
#        '서비스업생산지수(도소매업제외)(전월비)(%)', '건설기성액(전월비)(%)', '소매판매액지수(전월비)(%)',
#        '내수출하지수(전월비)(%)', '수입액(전월비)(%)', '비농림어업취업자수(전월비)(%)', '동행지수 순환변동치',
#        '〔순환변동치 전월차〕(p)', '후행종합지수(2020=100)', '후행종합지수 전월비(%)',
#        '생산자제품재고지수(전월비)(%)', '소비자물가지수변화율(서비스)(전월차)(%p)', '소비재수입액(전월비)(%)',
#        '취업자수(전월비)(%)', 'CP유통수익률(전월차)(%p)'],
#       dtype='object', name='지수별')

# %%
df["코스피(1980.1.4=100)"].tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\anaconda3\envs\forest_ex\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:219, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:227, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:119, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: '코스피(1980.1.4=100)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 df["코스피(1980.1.4=100)"].tail()
#
# File C:\anaconda3\envs\forest_ex\Lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File C:\anaconda3\envs\forest_ex\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: '코스피(1980.1.4=100)'

# %%
sns.regplot(data=df, x=' 선행종합지수(2020=100)', y='코스피(1980.1.4=100)')
# Out:
# <Axes: xlabel=' 선행종합지수(2020=100)', ylabel='코스피(1980.1.4=100)'>

# %%
sns.regplot(data=df, x=' 선행종합지수(2020=100)', y=' CP유통수익률(%p)')
# Out:
# <Axes: xlabel=' 선행종합지수(2020=100)', ylabel=' CP유통수익률(%p)'>

# %%
# print(df.tail(3).to_markdown())

# %%
df.describe().T.style.background_gradient()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\anaconda3\envs\forest_ex\Lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File C:\anaconda3\envs\forest_ex\Lib\site-packages\pandas\io\formats\style.py:408, in Styler._repr_html_(self)
#     403 """
#     404 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     405 default if an object is returned at the end of a cell.
#     406 """
#     407 if get_option("styler.render.repr") == "html":
# --> 408     return self.to_html()
#     409 return None
#
# File C:\anaconda3\envs\forest_ex\Lib\site-packages\pandas\io\formats\style.py:1348, in Styler.to_html(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    1345     obj.set_caption(caption)
#    1347 # Build HTML string..
# -> 1348 html = obj._render_html(
#    1349     sparse_index=sparse_index,
#    1350     sparse_columns=sparse_columns,
#    1351     max_rows=max_rows,
#    1352     max_cols=max_columns,
#    1353     exclude_styles=exclude_styles,
#    1354     encoding=encoding or get_option("styler.render.encoding"),
#    1355     doctype_html=doctype_html,
#    1356     **kwargs,
#    1357 )
#    1359 return save_to_buffer(
#    1360     html, buf=buf, encoding=(encoding if buf is not None else None)
#    1361 )
#
# File C:\anaconda3\envs\forest_ex\Lib\site-packages\pandas\io\formats\style_render.py:204, in StylerRenderer._render_html(self, sparse_index, sparse_columns, max_rows, max_cols, **kwargs)
#     192 def _render_html(
#     193     self,
#     194     sparse_index: bool,
#    (...)
#     198     **kwargs,
#     199 ) -> str:
#     200     """
#     201     Renders the ``Styler`` including all applied styles to HTML.
#     202     Generates a dict with necessary kwargs passed to jinja2 template.
#     203     """
# --> 204     d = self._render(sparse_index, sparse_columns, max_rows, max_cols, "&nbsp;")
#     205     d.update(kwargs)
#     206     return self.template_html.render(
#     207         **d,
#     208         html_table_tpl=self.template_html_table,
#     209         html_style_tpl=self.template_html_style,
#     210     )
#
# File C:\anaconda3\envs\forest_ex\Lib\site-packages\pandas\io\formats\style_render.py:161, in StylerRenderer._render(self, sparse_index, sparse_columns, max_rows, max_cols, blank)
#     147 def _render(
#     148     self,
#     149     sparse_index: bool,
#    (...)
#     153     blank: str = "",
#     154 ):
#     155     """
#     156     Computes and applies styles and then generates the general render dicts.
#     157
#     158     Also extends the `ctx` and `ctx_index` attributes with those of concatenated
#     159     stylers for use within `_translate_latex`
#     160     """
# --> 161     self._compute()
#     162     dxs = []
#     163     ctx_len = len(self.index)
#
# File C:\anaconda3\envs\forest_ex\Lib\site-packages\pandas\io\formats\style_render.py:256, in StylerRenderer._compute(self)
#     254 r = self
#     255 for func, args, kwargs in self._todo:
# --> 256     r = func(self)(*args, **kwargs)
#     257 return r
#
# File C:\anaconda3\envs\forest_ex\Lib\site-packages\pandas\io\formats\style.py:1755, in Styler._apply(self, func, axis, subset, **kwargs)
#    1751 if not all(result.columns.isin(data.columns)):
#    1752     raise ValueError(
#    1753         msg.format("columns", result.columns.shape, data.columns.shape)
#    1754     )
# -> 1755 self._update_ctx(result)
#    1756 return self
#
# File C:\anaconda3\envs\forest_ex\Lib\site-packages\pandas\io\formats\style.py:1552, in Styler._update_ctx(self, attrs)
#    1539 """
#    1540 Update the state of the ``Styler`` for data cells.
#    1541
#    (...)
#    1549     matter.
#    1550 """
#    1551 if not self.index.is_unique or not self.columns.is_unique:
# -> 1552     raise KeyError(
#    1553         "`Styler.apply` and `.map` are not compatible "
#    1554         "with non-unique index or columns."
#    1555     )
#    1557 for cn in attrs.columns:
#    1558     j = self.columns.get_loc(cn)
#
# KeyError: '`Styler.apply` and `.map` are not compatible with non-unique index or columns.'

# %%
df.filter(like="종합지수").plot(subplots=True);

# %%
col_total = df.filter(like="종합지수").columns
col_total
# Out:
# Index([' 선행종합지수(2020=100)', ' 동행종합지수(2020=100)', ' 후행종합지수(2020=100)'], dtype='object')

# %%
df.drop(columns=col_total).iloc[:, :6].plot(subplots=True, figsize=(12, 8));

# %%
df.drop(columns=col_total).iloc[:, 6:12].plot(subplots=True, figsize=(12, 8));

# %%
df.drop(columns=col_total).iloc[:, 12:].plot(subplots=True, figsize=(12, 8));

# %%
# df.plot(figsize=(15, 15))
